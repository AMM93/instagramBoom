# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep, strftime
from random import randint
import pandas as pd



chromedriver_path = '/Users/tono/Downloads/chromedriver' # Change this to your own chromedriver path!
webdriver = webdriver.Chrome(executable_path=chromedriver_path)
sleep(3)
webdriver.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
sleep(3)


username = webdriver.find_element_by_name('username')
username.send_keys('mexicanaenmadrid')
password = webdriver.find_element_by_name('password')
password.send_keys('DisneyAntonio07')

button_login = webdriver.find_element_by_css_selector('#react-root > section > main > div > article > div > div:nth-child(1) > div > form > div:nth-child(4) > button')
button_login.click()
sleep(3)

notifications = webdriver.find_element_by_xpath('/html/body/div[4]/div/div/div[3]/button[2]')
notifications.click()
sleep(3)

print("Desactivada notificaciones")



hashtag_list = ['mexicocity']


prev_user_list = []  # - if it's the first time you run it, use this line and comment the two below

#prev_user_list = pd.read_csv('Hackeados.csv', delimiter=',').iloc[:,1:2] # useful to build a user log


new_followed = []
tag = -1
followed = 0
likes = 0
comments = 0

for hashtag in hashtag_list:
    tag += 1
    webdriver.get('https://www.instagram.com/explore/tags/' + hashtag_list[tag] + '/')
    sleep(5)
    first_thumbnail = webdriver.find_element_by_xpath(
        '//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div')
    first_thumbnail.click()
    sleep(randint(1, 10))
    count = 0
    for x in range(1, 30):

        username = "/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a"
        follow_button = "/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[2]/button"
        if count < 5: 
            try:
                if webdriver.find_element_by_xpath(
                        follow_button).text == 'Follow':
                    print("No sabiamos de este usuario nada previamente")


                    new_followed.append(username)

                    follow = webdriver.find_element_by_xpath(follow_button)

                    follow.click()
                    print(" seguido")

                    followed += 1
                    sleep(randint(5, 10))

                    # Liking the picture
                    button_like = webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]/button')
                    button_like.click()
                    print("Like it!")
                    likes += 1
                    sleep(randint(5, 20))

                    comm_prob = randint(1, 30)
                    print('{}_{}: {}'.format(hashtag, x, comm_prob))
                    comment_icon = '/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[2]/button'
                    webdriver.find_element_by_xpath(comment_icon).click()

                    comment_box = webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/textarea')

                    if comm_prob >7:

                        comment_box.send_keys('Mexico!!')
                        sleep(randint(2, 6))

                    if (comm_prob < 7):

                        comment_box.send_keys('Really cool!')
                        sleep(4)

                    elif (comm_prob > 6) and (comm_prob < 9):
                        comment_box.send_keys('Enjoy it!!! :)')
                        sleep(4)
                    elif comm_prob == 9:
                        comment_box.send_keys('Nice shot!!')
                        sleep(3)
                    elif comm_prob == 10:
                        comment_box.send_keys('Wow! So cute')
                        sleep(10)
                        # Enter to post comment
                        comment_box.send_keys(Keys.ENTER)
                        sleep(randint(5, 10))
                    count += 1

                    try:   
                        webdriver.find_element_by_xpath('/html/body/div[4]/div[1]/div/div/a[2]').click()
                        sleep(randint(1, 5))
                    except:
                        webdriver.find_element_by_xpath('/html/body/div[4]/div[1]/div/div/a').click()
                        sleep(randint(1, 5))               

                elif webdriver.find_element_by_xpath(follow_button).text == 'Following':
                    print("ya seguimos a este usuario")
                    sleep(randint(1, 3))
                    try:   
                        webdriver.find_element_by_xpath('/html/body/div[4]/div[1]/div/div/a[2]').click()
                        sleep(randint(1, 5))
                    except:
                        webdriver.find_element_by_xpath('/html/body/div[4]/div[1]/div/div/a').click()
                        sleep(randint(1, 5))
            except:
                continue
        else:
            sleep(randint(30, 60))
            count = 0

for n in range(0, len(new_followed)):
    prev_user_list.append(new_followed[n])

updated_user_df = pd.DataFrame(prev_user_list)
updated_user_df.to_csv('Hackeados.csv')
print('Liked {} photos.'.format(likes))
print('Commented {} photos.'.format(comments))
print('Followed {} new people.'.format(followed))
# Out:
# Desactivada notificaciones
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_1: 21
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_2: 23
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_3: 11
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_4: 11
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_5: 30
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_7: 17
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_8: 1
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_9: 23
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_10: 6
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_11: 24
# No sabiamos de este usuario nada previamente
#  seguido
# Like it!
# mexicocity_13: 22
# ...

# %%
updated_user_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
